# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
import DataframeBuilder

# %%
target_type_list = ["TotalPrice", "TotalPartsSold"]
presence_type = "continuous"
quantile_threshold_list = [0.1, 0.5] # Controls the proportion of the lowest popularity vehicle types to be dropped
imputation_multiplier_list = [2, 3, 4] # Controls the number of times the dataframe records are duplicated

# %%
for target_type in target_type_list:
    for quantile_threshold in quantile_threshold_list:
        for imputation_multiplier in imputation_multiplier_list:
            
            vehicle_presence_df = DataframeBuilder.vehicle_presence(presence_type=presence_type, vehicle_type="year_model", target_type=target_type)
            
            # Create additional records based on the imputation multiplier
            vehicle_presence_df = pd.concat([vehicle_presence_df] * imputation_multiplier, ignore_index=True)
            
            if presence_type == "continuous":
                
              
                if 'TotalPrice' in vehicle_presence_df.columns:
                    sums = vehicle_presence_df.drop(columns=['TotalPrice', 'Date']).sum()
                    
                elif 'TotalPartsSold' in vehicle_presence_df.columns:
                    sums = vehicle_presence_df.drop(columns=['TotalPartsSold', 'Date']).sum()
                
                
                try:
                    # Determine the threshold for the bottom x% of sums
                    threshold = sums.quantile(quantile_threshold)
                
            
                    # Find columns to drop
                    cols_to_drop = sums[sums <= threshold].index.tolist()
            
                    # Drop columns from the dataframe
                    vehicle_presence_df = vehicle_presence_df.drop(columns=cols_to_drop)
                    
                except ValueError:
                    print("Sums not found, TotalPrice and TotalPartsSold are not available in vehicle_presence_df.")
                    
            vehicle_presence_df.columns = vehicle_presence_df.columns.astype(str)
            
            # Create the machine learning model steps here, including training and testing LR
            # Separating features and target
            X = vehicle_presence_df.drop(columns=[target_type, 'Date'])
            y = vehicle_presence_df[target_type]
            
            # Normalize the features
            scaler = StandardScaler()
            X_scaled = scaler.fit_transform(X)
            
            # Split the data for training and testing
            X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
            
            # Initialize and fit the Lasso regression model
            lasso = Lasso()
            
            
            # Define the parameter grid
            param_grid = {'alpha': [1e-2, 1e-1, 1, 10, 100]}
            
            # Use GridSearchCV for tuning
            grid_search = GridSearchCV(estimator=lasso, param_grid=param_grid, cv=5, scoring='neg_mean_absolute_percentage_error', return_train_score=True)
            grid_search.fit(X_train, y_train)
            
            # Get the results
            results = grid_search.cv_results_
            
            # Create a DataFrame to display results
            results_df = pd.DataFrame({
                'alpha': results['param_alpha'],
                'mean_test_score': results['mean_test_score'],
                'std_test_score': results['std_test_score']
            })
            
            results_df.to_csv(f'{target_type}_{quantile_threshold}_{imputation_multiplier}_LASSO_Results.csv', index=False)
# Out:
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.220e+06, tolerance: 1.005e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.244e+06, tolerance: 9.480e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.114e+06, tolerance: 9.908e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.212e+06, tolerance: 9.754e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.253e+06, tolerance: 1.027e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.413e+06, tolerance: 1.005e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.723e+06, tolerance: 9.480e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.520e+06, tolerance: 9.908e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.023e+06, tolerance: 9.754e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.777e+06, tolerance: 1.027e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.436e+07, tolerance: 1.005e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.777e+07, tolerance: 9.480e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.128e+07, tolerance: 9.908e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.539e+07, tolerance: 9.754e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.522e+07, tolerance: 1.027e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.650e+06, tolerance: 1.237e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.044e+06, tolerance: 1.498e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.988e+06, tolerance: 1.463e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.969e+06, tolerance: 1.459e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.036e+06, tolerance: 1.498e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.894e+06, tolerance: 1.493e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.058e+07, tolerance: 1.498e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.983e+06, tolerance: 1.463e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.495e+06, tolerance: 1.459e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.684e+06, tolerance: 1.498e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.240e+06, tolerance: 1.493e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.324e+07, tolerance: 1.498e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.385e+07, tolerance: 1.463e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.473e+07, tolerance: 1.459e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.942e+07, tolerance: 1.498e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.693e+07, tolerance: 1.493e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.540e+06, tolerance: 1.853e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.838e+06, tolerance: 2.008e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.977e+06, tolerance: 1.982e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.630e+06, tolerance: 1.937e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.981e+06, tolerance: 1.928e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.912e+06, tolerance: 2.027e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.387e+07, tolerance: 2.008e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.390e+07, tolerance: 1.982e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.351e+07, tolerance: 1.937e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.320e+07, tolerance: 1.928e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.306e+07, tolerance: 2.027e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.060e+07, tolerance: 2.008e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.921e+07, tolerance: 1.982e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.009e+07, tolerance: 1.937e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.069e+07, tolerance: 1.928e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.797e+07, tolerance: 2.027e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.708e+06, tolerance: 2.471e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.478e+06, tolerance: 1.005e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.439e+06, tolerance: 9.480e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.422e+06, tolerance: 9.908e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.432e+06, tolerance: 9.754e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.459e+06, tolerance: 1.027e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.311e+06, tolerance: 1.005e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.628e+06, tolerance: 9.480e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.296e+06, tolerance: 9.908e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.827e+06, tolerance: 9.754e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.860e+06, tolerance: 1.027e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.656e+07, tolerance: 1.005e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.918e+07, tolerance: 9.480e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.640e+07, tolerance: 9.908e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.590e+07, tolerance: 9.754e+04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.510e+07, tolerance: 1.027e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.027e+07, tolerance: 1.237e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.404e+06, tolerance: 1.498e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.408e+06, tolerance: 1.463e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.414e+06, tolerance: 1.459e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.443e+06, tolerance: 1.498e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.259e+06, tolerance: 1.493e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.295e+07, tolerance: 1.498e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.260e+07, tolerance: 1.463e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.322e+07, tolerance: 1.459e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.276e+07, tolerance: 1.498e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.269e+07, tolerance: 1.493e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.947e+07, tolerance: 1.498e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.023e+07, tolerance: 1.463e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.302e+07, tolerance: 1.459e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.538e+07, tolerance: 1.498e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.885e+07, tolerance: 1.493e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.108e+06, tolerance: 1.853e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.394e+06, tolerance: 2.008e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.469e+06, tolerance: 1.982e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.135e+06, tolerance: 1.937e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.500e+06, tolerance: 1.928e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.345e+06, tolerance: 2.027e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.764e+07, tolerance: 2.008e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.755e+07, tolerance: 1.982e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.705e+07, tolerance: 1.937e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.683e+07, tolerance: 1.928e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.732e+07, tolerance: 2.027e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.214e+07, tolerance: 2.008e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.540e+07, tolerance: 1.982e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.741e+07, tolerance: 1.937e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.464e+07, tolerance: 1.928e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.593e+07, tolerance: 2.027e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.314e+06, tolerance: 2.471e+05
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.543e+04, tolerance: 2.120e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.721e+04, tolerance: 2.058e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.393e+04, tolerance: 2.062e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.449e+04, tolerance: 2.043e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.503e+04, tolerance: 2.093e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.006e+04, tolerance: 2.120e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.113e+04, tolerance: 2.058e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.571e+04, tolerance: 2.062e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.039e+04, tolerance: 2.043e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.451e+04, tolerance: 2.093e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.988e+04, tolerance: 2.595e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.629e+04, tolerance: 3.021e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.750e+04, tolerance: 3.062e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.778e+04, tolerance: 2.988e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.594e+04, tolerance: 3.097e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.112e+04, tolerance: 2.996e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.463e+04, tolerance: 3.021e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.853e+04, tolerance: 3.062e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.498e+04, tolerance: 2.988e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.316e+04, tolerance: 3.097e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.222e+04, tolerance: 2.996e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.569e+04, tolerance: 3.791e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.537e+04, tolerance: 4.128e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.921e+04, tolerance: 4.105e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.596e+04, tolerance: 4.104e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.685e+04, tolerance: 4.040e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.472e+04, tolerance: 4.139e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.237e+04, tolerance: 4.128e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.265e+04, tolerance: 4.105e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.458e+04, tolerance: 4.104e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.043e+04, tolerance: 4.040e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.214e+04, tolerance: 4.139e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.821e+04, tolerance: 5.129e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.026e+04, tolerance: 2.120e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.069e+04, tolerance: 2.058e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.899e+04, tolerance: 2.062e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.027e+04, tolerance: 2.043e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.992e+04, tolerance: 2.093e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.502e+04, tolerance: 2.120e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.122e+04, tolerance: 2.058e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.569e+04, tolerance: 2.062e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.934e+04, tolerance: 2.043e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.482e+04, tolerance: 2.093e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.519e+04, tolerance: 2.595e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.921e+04, tolerance: 3.021e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.314e+04, tolerance: 3.062e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.151e+04, tolerance: 2.988e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.921e+04, tolerance: 3.097e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.067e+04, tolerance: 2.996e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.398e+04, tolerance: 3.021e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.451e+04, tolerance: 3.062e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.918e+04, tolerance: 2.988e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.190e+04, tolerance: 3.097e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.201e+04, tolerance: 2.996e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.050e+04, tolerance: 3.791e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.625e+04, tolerance: 4.128e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.218e+04, tolerance: 4.105e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.348e+04, tolerance: 4.104e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.254e+04, tolerance: 4.040e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.046e+04, tolerance: 4.139e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.090e+04, tolerance: 4.128e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.156e+04, tolerance: 4.105e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.110e+04, tolerance: 4.104e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.427e+04, tolerance: 4.040e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.899e+04, tolerance: 4.139e+02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aljo9\PycharmProjects\NV_Picapart_Analysis\.venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.352e+04, tolerance: 5.129e+02
#   model = cd_fast.enet_coordinate_descent(
